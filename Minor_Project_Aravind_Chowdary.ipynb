# %% [markdown]
# # 1.Importing the Dataset

# %%
import numpy as np                                        #importing the pacakges required
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("datasets_4458_8204_winequality-red.csv")  #importing the dataset
df   #Pritning the dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # 2. Data Quality Check

# %%
df=df[(df != 0).all(1)]  # droping all the rows that have atleast one null value and storing the remaining
df                       # Pritning the dataset after droping the rows with null values
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # 3.Exploratory Data Analysis

# %% [markdown]
# ## a. Univariate Anaylsis

# %% [markdown]
# ### Histogarms

# %%
col_list=sorted(df)               # Storing all the coloumn labels in one list in alphabetical order
for x in range(0,12):             # Iterating the loop for all the coloumn labels
    plt.hist(df[col_list[x]])
    plt.title(col_list[x])        # Pritning the title of the plot
    plt.show()                    # Plotting the Histogram
    plt.clf()

# %% [markdown]
# ### Box Plots

# %%
for x in range(0,12):               # Iterating the loop for all the coloumn labels
    plt.boxplot(df[col_list[x]])
    plt.title(col_list[x])          # Pritning the title of the plot
    plt.show()                      # Plotting the Box plot
    plt.clf()

# %% [markdown]
# ## b. Bivariate Analysis

# %% [markdown]
# ### Scatter Plots

# %%
for x in range(0,12):                # Iterating the loop for all the coloumn labels
    a=df[col_list[x]]
    y=df["quality"]
    plt.scatter(a,y)
    plt.xlabel(col_list[x])
    plt.ylabel("quality")
    plt.show()                        # Plotting the Scatter plot
    plt.clf()

# %% [markdown]
# # 4. MODELLING

# %% [markdown]
# ## a. Train Test Split

# %%
from sklearn.model_selection import train_test_split          #importing the pacakges required
X=df.drop(["quality"],axis=1).values
Y=df["quality"].values
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.25,random_state=40,stratify=Y)
# The test_size and random_state though alloted randomly, but are checked several times 
# whether they give a good test and train scores or not.

# %% [markdown]
# ## b. KNN Classification

# %%
from sklearn.neighbors import KNeighborsClassifier          #importing the pacakges required
n_neighbors=[]
for i in range(2,50):
    n_neighbors.append(i)
score = []
for a in n_neighbors:
    knn=KNeighborsClassifier(n_neighbors=a)
    knn.fit(X_train,Y_train)
    score.append(knn.score(X_test,Y_test))
m = score.index(max(score))
n = n_neighbors[m]
n
# Out:
# 4

# %%
knn=KNeighborsClassifier(n_neighbors=n)
knn.fit(X_train,Y_train)
knn.score(X_train,Y_train)                                  # Train score
# Out:
# 0.6672727272727272

# %%
knn.score(X_test,Y_test)                                    # Test score
# Out:
# 0.5831062670299727

# %% [markdown]
# ## d. Prediction on test set in KNN Classification

# %%
Y_pred=knn.predict(X_test)
Y_pred                                                      # Y prediction values for X_test
# Out:
# array([6, 7, 6, 5, 6, 6, 6, 5, 5, 6, 6, 5, 7, 5, 6, 5, 6, 5, 5, 6, 7, 5,
#        5, 5, 7, 6, 6, 5, 7, 6, 6, 6, 5, 6, 6, 6, 5, 6, 6, 5, 7, 5, 5, 5,
#        5, 6, 5, 6, 6, 7, 6, 5, 5, 5, 6, 6, 5, 7, 6, 5, 7, 7, 6, 5, 5, 5,
#        6, 5, 6, 6, 5, 5, 6, 5, 5, 6, 6, 5, 7, 6, 5, 6, 5, 6, 6, 6, 5, 5,
#        5, 5, 6, 5, 5, 5, 5, 5, 5, 7, 5, 6, 8, 7, 6, 5, 5, 6, 5, 4, 5, 5,
#        6, 5, 5, 7, 5, 6, 5, 5, 6, 6, 5, 5, 6, 7, 7, 6, 5, 6, 5, 6, 6, 5,
#        5, 5, 5, 6, 6, 6, 5, 6, 6, 5, 4, 5, 6, 5, 5, 6, 7, 6, 5, 5, 5, 5,
#        6, 5, 5, 6, 5, 5, 6, 5, 5, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6,
#        5, 6, 5, 7, 5, 6, 5, 5, 5, 6, 6, 5, 5, 5, 7, 5, 6, 5, 7, 6, 5, 5,
#        5, 6, 6, 5, 5, 6, 5, 7, 5, 6, 6, 5, 5, 5, 5, 7, 5, 5, 5, 5, 6, 5,
#        5, 5, 5, 5, 6, 6, 5, 7, 6, 6, 6, 5, 6, 5, 5, 5, 6, 5, 5, 6, 6, 7,
#        5, 5, 6, 7, 6, 6, 5, 6, 6, 5, 5, 7, 5, 6, 6, 6, 6, 6, 5, 6, 5, 5,
#        5, 6, 5, 5, 5, 6, 5, 5, 5, 6, 5, 6, 5, 7, 5, 4, 7, 6, 5, 6, 7, 5,
# ...

# %% [markdown]
# ## e. Accuracy in KNN Classification

# %%
from sklearn.metrics import confusion_matrix                      #importing the pacakges required
from sklearn.metrics import classification_report
confusion_matrix(Y_test,Y_pred)                                   #Printing the Confusion matrix
# Out:
# array([[  0,   0,   1,   0,   1,   0],
#        [  0,   0,   8,   2,   1,   0],
#        [  0,   1, 119,  30,   6,   0],
#        [  0,   3,  56,  76,  11,   0],
#        [  0,   1,   7,  20,  19,   1],
#        [  0,   0,   2,   2,   0,   0]], dtype=int64)

# %%
print(classification_report(Y_test,Y_pred))                       #Printing the Classification report
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.62      0.76      0.68       156
#            6       0.58      0.52      0.55       146
#            7       0.50      0.40      0.44        48
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.58       367
#    macro avg       0.28      0.28      0.28       367
# weighted avg       0.56      0.58      0.57       367
# C:\Users\Satish\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## c. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression          #importing the pacakges required
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
logreg=LogisticRegression()
logreg.fit(X_train,Y_train)
logreg.score(X_train,Y_train)                                # Train score
# Out:
# C:\Users\Satish\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.5863636363636363

# %%
logreg.score(X_test,Y_test)                                  # Test score
# Out:
# 0.553133514986376

# %% [markdown]
# ## d. Prediction on test set in Logistic Regression

# %%
Y_pred=logreg.predict(X_test)
Y_pred                                                       # Y prediction values for X_test
# Out:
# array([6, 6, 6, 5, 6, 6, 6, 5, 6, 6, 6, 5, 6, 5, 6, 5, 6, 5, 5, 6, 6, 5,
#        5, 5, 6, 6, 6, 6, 6, 5, 5, 6, 6, 6, 6, 6, 7, 5, 5, 5, 6, 5, 5, 6,
#        5, 6, 5, 6, 6, 6, 6, 6, 5, 5, 5, 6, 5, 6, 5, 5, 6, 6, 6, 5, 6, 5,
#        6, 6, 6, 5, 5, 6, 5, 5, 6, 5, 6, 6, 5, 5, 6, 5, 6, 5, 6, 6, 5, 5,
#        5, 5, 6, 5, 5, 5, 6, 6, 6, 6, 5, 6, 6, 6, 6, 5, 5, 6, 5, 5, 5, 5,
#        5, 5, 5, 6, 5, 6, 5, 6, 6, 6, 5, 5, 6, 6, 6, 6, 5, 6, 5, 6, 6, 5,
#        6, 5, 6, 6, 6, 6, 5, 6, 6, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 5, 5,
#        6, 6, 5, 6, 6, 5, 6, 5, 5, 6, 6, 5, 6, 6, 5, 5, 5, 6, 5, 6, 6, 6,
#        6, 5, 5, 6, 5, 5, 6, 5, 6, 6, 5, 5, 5, 5, 6, 5, 5, 5, 6, 6, 5, 5,
#        5, 6, 7, 6, 6, 5, 5, 7, 5, 6, 6, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 6,
#        5, 6, 5, 5, 6, 6, 5, 6, 5, 6, 5, 5, 6, 6, 5, 5, 6, 6, 5, 6, 6, 5,
#        5, 5, 6, 6, 6, 6, 5, 6, 6, 6, 5, 6, 5, 5, 6, 6, 5, 6, 5, 5, 5, 6,
#        5, 6, 5, 6, 6, 6, 5, 5, 6, 5, 5, 6, 6, 6, 5, 6, 6, 5, 5, 6, 6, 6,
# ...

# %% [markdown]
# ## e. Accuracy in Logistic Regression

# %%
confusion_matrix(Y_test,Y_pred)                            #Printing the Confusion matrix
# Out:
# array([[  0,   0,   2,   0,   0,   0],
#        [  0,   0,   6,   5,   0,   0],
#        [  0,   0, 112,  44,   0,   0],
#        [  0,   0,  52,  91,   3,   0],
#        [  0,   0,   3,  45,   0,   0],
#        [  0,   0,   0,   4,   0,   0]], dtype=int64)

# %%
print(classification_report(Y_test,Y_pred))               #Printing the Classification report
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.64      0.72      0.68       156
#            6       0.48      0.62      0.54       146
#            7       0.00      0.00      0.00        48
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.55       367
#    macro avg       0.19      0.22      0.20       367
# weighted avg       0.46      0.55      0.50       367
# C:\Users\Satish\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
